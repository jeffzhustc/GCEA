# %%
from rdkit import Chem
from case_study.draw_mol import Draw_smi
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import QED

# %%
smi1 = 'COC1=CC(CNC(=N)C2=C(C)C=CO2)=CC=N1'
smi2 = 'COC1=CC(CNC(=O)C2=C(C)C=CO2)=CC=N1'
mol1 = Chem.MolFromSmiles(smi1)
mol2 = Chem.MolFromSmiles(smi2)
mol1

# %%
mol2

# %%
img1 = Draw.MolToImage(mol1)
img2 = Draw.MolToImage(mol2)
img1.save('case1.png')
img2.save('case2.png')

# %%
qed1 = 'QED:'+str(QED.qed(mol1))
qed2 = 'QED:'+str(QED.qed(mol2))
qed1
# Out:
# 'QED:0.6389289563885511'

# %%
img = Draw.MolsToGridImage([mol1,mol2],molsPerRow=1,legends=[qed1,qed2])

# %%
img.save('D:\\0Lab\ML\\repo\GCEA\case_study\case3.png')

# %%
img1 = Draw.MolToImage(mol1)
img2 = Draw.MolToImage(mol2)
img1.save('case1.png')
img2.save('case2.png')
img1
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x26FC9666358>

# %%
Draw.MolToFile(mol2,'D:\\0Lab\ML\\repo\GCEA\case_study\case2.pdf')
